# %% [markdown]
# ### 1. Setup

# %%
import json
import getpass
import os
from tqdm import tqdm
import requests
import time
import uuid
from uuid import uuid4
from pathlib import Path

# %%
# !pip install beautifulsoup4 lxml
# !pip install unstructured
# !pip install -qU "langchain-chroma>=0.1.2"
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (4.12.3)
# Requirement already satisfied: lxml in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (5.3.0)
# Requirement already satisfied: soupsieve>1.2 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: unstructured in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (0.16.5)
# Requirement already satisfied: chardet in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: filetype in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (5.3.0)
# Requirement already satisfied: nltk in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (4.12.3)
# Requirement already satisfied: emoji in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (2.14.0)
# Requirement already satisfied: dataclasses-json in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (2024.10.22)
# Requirement already satisfied: langdetect in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy<2 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (1.26.4)
# Requirement already satisfied: rapidfuzz in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (3.10.1)
# Requirement already satisfied: backoff in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (4.12.2)
# Requirement already satisfied: unstructured-client in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (0.27.0)
# Requirement already satisfied: wrapt in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (1.16.0)
# Requirement already satisfied: tqdm in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (4.67.0)
# Requirement already satisfied: psutil in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (6.1.0)
# Requirement already satisfied: python-oxmsg in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (0.0.1)
# Requirement already satisfied: html5lib in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from dataclasses-json->unstructured) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from html5lib->unstructured) (1.16.0)
# Requirement already satisfied: webencodings in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from nltk->unstructured) (2024.11.6)
# Requirement already satisfied: olefile in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from requests->unstructured) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from requests->unstructured) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from requests->unstructured) (2024.8.30)
# Requirement already satisfied: cryptography>=3.1 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured-client->unstructured) (43.0.3)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured-client->unstructured) (0.2.0)
# Requirement already satisfied: httpx>=0.27.0 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured-client->unstructured) (0.27.2)
# Requirement already satisfied: jsonpath-python<2.0.0,>=1.0.6 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.9.2 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured-client->unstructured) (2.9.2)
# Requirement already satisfied: pypdf>=4.0 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured-client->unstructured) (5.1.0)
# Requirement already satisfied: python-dateutil==2.8.2 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured-client->unstructured) (2.8.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: anyio in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.6)
# Requirement already satisfied: sniffio in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/geonheekim/miniconda3/envs/gpt/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.2.2)

# %%
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    # Legacy Python that doesn't verify HTTPS certificates by default
    pass
else:
    # Handle target environment that doesn't support HTTPS verification
    ssl._create_default_https_context = _create_unverified_https_context

# %%
import requests

# Disable SSL verification globally
requests.packages.urllib3.disable_warnings(requests.packages.urllib3.exceptions.InsecureRequestWarning)

# %%
os.environ["NCP_CLOVASTUDIO_API_KEY"] = getpass.getpass("NCP CLOVA Studio API Key: ")
os.environ["NCP_APIGW_API_KEY"] = getpass.getpass("NCP API Gateway API Key: ")

# %%
os.environ["NCP_CLOVASTUDIO_APP_ID"] = input("NCP CLOVA Studio App ID: ")

# %%
os.environ["NCP_CLOVASTUDIO_APP_ID_SEGMENTATION"] = input("NCP CLOVA Studio Segmentation App ID: ")

# %%
from langchain_community.embeddings import ClovaXEmbeddings
 
clovax_embeddings = ClovaXEmbeddings(model='bge-m3') # 임베딩 모델을 설정해주세요

# %% [markdown]
# ### 2. Load

# %%
import subprocess
 
url_to_filename_map = {}
  
with open("clovastudiourl.txt", "r") as file:
    urls = [url.strip() for url in file.readlines()]
  
folder_path = "clovastudioguide"
  
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
  
for url in urls:
    filename = url.split("/")[-1] + ".html"
    file_path = os.path.join(folder_path, filename)
    subprocess.run(["wget", "--user-agent=RAGCookbook-Crawler/1.0", "-O", file_path, url], check=True)
    url_to_filename_map[url] = filename
  
with open("url_to_filename_map.json", "w") as map_file:
    json.dump(url_to_filename_map, map_file)
# Out:
# --2024-11-13 09:14:46--  https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1
# Resolving deviparikh.medium.com (deviparikh.medium.com)... 162.159.153.4, 162.159.152.4, 2606:4700:7::a29f:9904, ...
# Connecting to deviparikh.medium.com (deviparikh.medium.com)|162.159.153.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘clovastudioguide/how-we-write-rebuttals-dc84742fece1.html’
#
#      0K .......... .......... .......... .......... .......... 3.17M
#     50K .......... .......... .......... .......... .......... 3.75M
#    100K .......... .......... .......... .......... .......... 2.90M
#    150K .......... .......... .......... .......... .......    12.2M=0.05s
#
# 2024-11-13 09:14:46 (3.93 MB/s) - ‘clovastudioguide/how-we-write-rebuttals-dc84742fece1.html’ saved [201960]

# %%
#!pip install beautifulsoup4 lxml #필요시 beautifulsoup4 설치
from langchain_community.document_loaders import BSHTMLLoader
 
# 폴더 이름에 맞게 수정
html_files_dir = Path('clovastudioguide')
  
html_files = list(html_files_dir.glob("*.html"))
  
# 모든 문서 데이터를 저장할 리스트 초기화
clovastudiodatas = []
  
# 찾은 HTML 파일들에 대해 처리
for html_file in html_files:
    # 각 파일에 대해 BSHTMLLoader 인스턴스 생성
    loader = BSHTMLLoader(str(html_file))
    document_data = loader.load()
    # 로드된 문서 데이터를 리스트에 추가
    clovastudiodatas.append(document_data)
    print(f"Processed {html_file}")
# Out:
# Processed clovastudioguide/how-we-write-rebuttals-dc84742fece1.html

# %%
#!pip install unstructured #필요시 unstructured 설치
from langchain_community.document_loaders import UnstructuredHTMLLoader
 
# 폴더 이름에 맞게 수정
html_files_dir = Path('./clovastudioguide')
  
html_files = list(html_files_dir.glob("*.html"))
  
clovastudiodatas = []
  
for html_file in html_files:
    loader = UnstructuredHTMLLoader(str(html_file))
    document_data = loader.load()
    clovastudiodatas.append(document_data)
    print(f"Processed {html_file}")
# Out:
# Processed clovastudioguide/how-we-write-rebuttals-dc84742fece1.html

# %%
with open("url_to_filename_map.json", "r") as map_file:
    url_to_filename_map = json.load(map_file)
  
filename_to_url_map = {v: k for k, v in url_to_filename_map.items()}
  
# clovastudiodatas 리스트의 각 Document 객체의 'source' 수정
for doc_list in clovastudiodatas:
    for doc in doc_list:
        extracted_filename = doc.metadata["source"].split("/")[-1]
        if extracted_filename in filename_to_url_map:
            doc.metadata["source"] = filename_to_url_map[extracted_filename]
        else:
            print(f"Warning: {extracted_filename}에 해당하는 URL을 찾을 수 없습니다.")
print(doc.metadata["source"])
# Out:
# https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1

# %%
# 이중 리스트를 풀어서 하나의 리스트로 만드는 작업
clovastudiodatas_flattened = [item for sublist in clovastudiodatas for item in sublist]

# %%
# 처음 3개 문서의 URL과 내용 일부 출력
for doc in clovastudiodatas_flattened[:2]:
    print(f"URL: {doc.metadata['source']}")
    print(f"{doc.page_content[:100]}...")
    print("-" * 50)
# Out:
# URL: https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1
# Open in app
#
# Sign in
#
# Write
#
# Sign in
#
# How we write rebuttals
#
# Devi Parikh
#
# Follow
#
# 10 min read
#
# May ...
# --------------------------------------------------

# %% [markdown]
# ### 3. Chunking

# %%
import http.client
from http import HTTPStatus
  
class CLOVAStudioExecutor:
    def __init__(self, host, request_id=None):
        self._host = host
        self._api_key = os.environ["NCP_CLOVASTUDIO_API_KEY"]
        self._api_key_primary_val = os.environ["NCP_APIGW_API_KEY"]
        self._request_id = request_id or str(uuid.uuid4())
  
    def _send_request(self, completion_request, endpoint):
        headers = {
            'Content-Type': 'application/json; charset=utf-8',
            'X-NCP-CLOVASTUDIO-API-KEY': self._api_key,
            'X-NCP-APIGW-API-KEY': self._api_key_primary_val,
            'X-NCP-CLOVASTUDIO-REQUEST-ID': self._request_id
        }
  
        conn = http.client.HTTPSConnection(self._host)
        conn.request('POST', endpoint, json.dumps(completion_request), headers)
        response = conn.getresponse()
        status = response.status
        result = json.loads(response.read().decode(encoding='utf-8'))
        conn.close()
        return result, status
  
    def execute(self, completion_request, endpoint):
        res, status = self._send_request(completion_request, endpoint)
        if status == HTTPStatus.OK:
            return res, status
        else:
            error_message = res.get("status", {}).get("message", "Unknown error") if isinstance(res, dict) else "Unknown error"
            raise ValueError(f"오류 발생: HTTP {status}, 메시지: {error_message}")
  
class SegmentationExecutor(CLOVAStudioExecutor):
    def execute(self, completion_request):
        app_id = os.environ["NCP_CLOVASTUDIO_APP_ID_SEGMENTATION"]
        endpoint = f'/testapp/v1/api-tools/segmentation/{app_id}'
        res, status = super().execute(completion_request, endpoint)
        if status == HTTPStatus.OK and "result" in res:
            return res["result"]["topicSeg"]
        else:
            error_message = res.get("status", {}).get("message", "Unknown error") if isinstance(res, dict) else "Unknown error"
            raise ValueError(f"오류 발생: HTTP {status}, 메시지: {error_message}")
         
if __name__ == "__main__":
    # 환경 변수가 설정되어 있는지 확인
    required_env_vars = [
        "NCP_CLOVASTUDIO_API_KEY",
        "NCP_APIGW_API_KEY",
        "NCP_CLOVASTUDIO_APP_ID_SEGMENTATION"
    ]
     
    missing_vars = [var for var in required_env_vars if not os.environ.get(var)]
    if missing_vars:
        raise ValueError(f"Missing required environment variables: {', '.join(missing_vars)}")
     
    segmentation_executor = SegmentationExecutor(
        host="clovastudio.apigw.ntruss.com"
    )
  
    chunked_html = []
  
    for htmldata in tqdm(clovastudiodatas_flattened):
        try:
            request_data = {
                "postProcessMaxSize": 100,
                "alpha": -100,
                "segCnt": -1,
                "postProcessMinSize": -1,
                "text": htmldata.page_content,
                "postProcess": True
            }
              
            response_data = segmentation_executor.execute(request_data)
            result_data = [' '.join(segment) for segment in response_data]
      
            for paragraph in result_data:
                chunked_document = {
                    "metadata": htmldata.metadata["source"],
                    "page_content": paragraph
                }
                chunked_html.append(chunked_document)
      
        except Exception as e:
            print(f"Error processing data from {htmldata.metadata['source']}: {e}")
            # 오류 발생 시 현재 반복을 건너뛰고 다음으로 진행
            continue
   
    print(len(chunked_html))
# Out:
# 100%|██████████| 1/1 [00:03<00:00,  3.77s/it]
# 113

# %%
chunked_html[40]
# Out:
# {'metadata': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1',
#  'page_content': 'And then give details, describe context, or explain your position.'}

# %%
# 청크 분석 및 출력
print(f"\n총 청크 수: {len(chunked_html)}")
 
# 샘플 청크 출력
print("\n샘플 청크 (처음 3개):")
for i, chunk in enumerate(chunked_html[:3], 1):
    print(f"\n청크 {i}:")
    print(f"메타데이터: {chunk['metadata']}")
    print(f"내용: {chunk['page_content']}")
    print(f"길이: {len(chunk['page_content'])} 문자")
# Out:
# 총 청크 수: 113
#
# 샘플 청크 (처음 3개):
#
# 청크 1:
# 메타데이터: https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1
# 내용: Open in app Sign in Write Sign in How we write rebuttals Devi Parikh Follow 10 min read May 27, 2020 --
# 길이: 103 문자
#
# 청크 2:
# 메타데이터: https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1
# 내용: By Devi Parikh, Dhruv Batra, Stefan Lee We frequently find ourselves giving the same advice to different students on how to write rebuttals.
# 길이: 140 문자
#
# 청크 3:
# 메타데이터: https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1
# 내용: So we thought we’d write it up. Our experience is with AI conferences (e.g., CVPR, ECCV, ICCV, NeurIPS, ICLR, EMNLP).The core guiding principle is that the rebuttal should be thorough, direct, and easy for the Reviewers and Area Chair (RACs) to follow.
# 길이: 252 문자

# %% [markdown]
# ### 4. Embedding

# %%
import requests 
from requests.packages.urllib3.exceptions import InsecureRequestWarning 
# Suppress only the single InsecureRequestWarning from urllib3 needed for this snippet 
requests.packages.urllib3.disable_warnings(InsecureRequestWarning) 
# Modify the default behavior of the requests to not verify SSL certificates 
requests.Session().verify = False

# %%
# -*- coding: utf-8 -*-

class EmbeddingExecutor:
    def __init__(self, host, api_key, api_key_primary_val, request_id):
        self._host = host
        self._api_key = api_key
        self._api_key_primary_val = api_key_primary_val
        self._request_id = request_id

    def _send_request(self, completion_request):
        headers = {
            'Content-Type': 'application/json; charset=utf-8',
            'X-NCP-CLOVASTUDIO-API-KEY': self._api_key,
            'X-NCP-APIGW-API-KEY': self._api_key_primary_val,
            'X-NCP-CLOVASTUDIO-REQUEST-ID': self._request_id
        }

        conn = http.client.HTTPSConnection(self._host)
        conn.request('POST', '/testapp/v1/api-tools/embedding/v2/2c9ce8f0ca6843e49d98ff0ea46efdd2', json.dumps(completion_request), headers)
        response = conn.getresponse()
        result = json.loads(response.read().decode(encoding='utf-8'))
        conn.close()
        return result

    def execute(self, completion_request):
        res = self._send_request(completion_request)
        if res['status']['code'] == '20000':
            return res['result']['embedding']
        else:
            return 'Error'

# %%
embedding_executor = EmbeddingExecutor(
    host='clovastudio.apigw.ntruss.com',
    api_key= os.environ["NCP_CLOVASTUDIO_API_KEY"],
    api_key_primary_val = os.environ["NCP_APIGW_API_KEY"],
    request_id= os.environ["NCP_CLOVASTUDIO_APP_ID"]
)

request_data = json.loads("""{
"text" : "input text"
}""", strict=False)

response_text = embedding_executor.execute(request_data)
print(request_data)
print(response_text)
print(len(response_text))
# Out:
# {'text': 'input text'}
# [-0.9326172, 0.69628906, -0.515625, 0.12683105, -0.29736328, -0.55615234, 0.2388916, 0.15234375, 0.40039062, -0.68359375, 0.29541016, -0.047424316, 0.36669922, -0.81689453, -0.2619629, -0.34375, -0.16601562, 0.36743164, 0.17993164, -0.2705078, -0.80078125, -0.24499512, -0.08093262, 0.34033203, 0.47387695, 0.9682617, 0.2866211, -0.42407227, -0.58154297, -0.20178223, 0.87646484, 0.0181427, -0.7939453, -2.0625, 0.31201172, -0.11657715, -0.12573242, -0.3149414, -1.5751953, 0.27807617, 0.087524414, -0.59716797, 0.55615234, -0.022842407, -0.27807617, -0.081970215, 1.0087891, -0.39575195, -0.7050781, -0.5683594, 0.054107666, 0.52685547, 1.8037109, -0.1784668, -0.31225586, -0.5307617, -0.2388916, 0.16149902, -1.6572266, -0.07635498, -0.2788086, -0.54296875, -0.48706055, -0.27929688, -0.21374512, 1.7119141, 0.91308594, 0.13464355, -0.703125, -0.67089844, -0.33496094, 0.7866211, -0.3413086, -0.08496094, -1.2548828, 1.1201172, 0.6401367, -0.40893555, -0.41479492, 0.6435547, 0.6928711, -0.8774414, -0.6743164, 0.7836914, -0.36547852, 0.03201294, 0.39575195, -0.36523438, -0.42407227, 0.06011963, -0.21704102, -0.5961914, 1.6376953, -0.31445312, -0.17736816, -0.81103516, 0.07519531, 0.5292969, 0.43774414, 0.51953125, -0.013008118, 0.9511719, 0.55566406, 0.29638672, 1.4072266, 0.039916992, 1.9130859, 0.6303711, -0.18188477, 0.19335938, 0.28393555, 1.1601562, 0.5253906, 0.049804688, 0.8095703, -1.1865234, -0.82958984, -0.21374512, 0.72998047, -0.39526367, 1.2988281, 0.5830078, 0.6958008, -0.61816406, 0.41967773, -0.87597656, -0.04547119, 0.37231445, -0.42211914, -0.6845703, -0.25073242, 1.9433594, -0.22143555, 0.22290039, -0.6323242, -0.4909668, 0.24536133, 0.15136719, 1.1796875, -1.0537109, 0.27026367, 0.46948242, -1.5371094, -1.6171875, 0.9506836, -2.1230469, 0.7680664, -0.6069336, 0.6821289, -0.42163086, 0.26000977, 0.79296875, -0.0859375, 0.61816406, -0.5161133, -0.69433594, -1.1445312, -0.81396484, 0.44262695, 0.8256836, -0.18530273, 0.31225586, -1.4648438, -0.25219727, -0.018814087, 0.049316406, 0.9926758, 0.76220703, -0.16552734, -0.44848633, 0.016830444, 0.14575195, 1.3164062, -0.036499023, 0.41235352, 0.16870117, 1.7109375, 0.47998047, -0.45458984, -0.93066406, -0.7685547, 0.42138672, -0.05984497, -0.5620117, -0.26416016, 0.39916992, 0.32641602, 0.24084473, -0.32592773, 0.6958008, -0.80126953, -0.7504883, -0.17700195, -0.30981445, 0.7583008, 0.5546875, 0.61621094, -0.21374512, -1.1904297, -0.6738281, -1.390625, 0.45117188, -0.2487793, -1.1748047, -0.83251953, -0.2536621, -0.53515625, -0.9995117, 1.0009766, -0.51123047, 0.49291992, 0.9458008, 0.26123047, -0.42749023, -0.66308594, 0.33081055, 1.2695312, -0.5957031, 0.6064453, -0.73583984, -0.16491699, 0.8095703, 0.5234375, 0.5517578, 0.7260742, -0.3334961, 0.8540039, 0.58251953, -0.05731201, -1.3085938, 0.107910156, 0.30126953, -0.6503906, -1.0371094, -0.28125, 0.20141602, -0.4658203, 0.2355957, 0.58447266, 0.26098633, 0.24328613, -1.0878906, 0.8144531, 0.06719971, -0.07885742, 0.04232788, -0.062927246, 1.0068359, -0.13928223, -0.30786133, -0.3947754, 0.006916046, -0.84033203, 0.31323242, 0.7055664, 0.32495117, 0.41235352, 0.06817627, -0.30810547, 0.1463623, 0.029251099, -0.5756836, 0.7573242, 0.38330078, 0.45898438, 0.065979004, 0.43359375, -0.07055664, 0.31860352, -0.40307617, -1.4052734, -0.9555664, 0.17602539, -0.68603516, 0.12005615, 1.2880859, 0.049621582, -1.4882812, -0.06286621, 0.11254883, 0.29492188, 0.6088867, 0.060272217, -1.0878906, 0.38012695, 0.37524414, 0.45581055, -0.8408203, 0.27490234, -1.3144531, -0.74121094, -0.9194336, 1.53125, -0.24389648, -0.3720703, -0.27954102, -0.38183594, -4.1054688, -0.15075684, -1.5097656, 0.12646484, 1.2578125, 0.00074863434, -1.5634766, -0.73095703, -1.1601562, 0.24194336, -0.004787445, -1.4716797, -0.45214844, -1.0830078, 1.2041016, 0.058776855, -0.4555664, -0.671875, -0.25390625, -0.71240234, -0.21008301, -1.1220703, 1.796875, -0.83740234, -0.87158203, -0.8300781, 0.39672852, -1.703125, -0.734375, -0.004852295, -0.18188477, 0.048339844,  ...
# 1024

# %%
# ssl 
from langchain_community.embeddings import ClovaXEmbeddings
clovax_embeddings = ClovaXEmbeddings(model='bge-m3') # 임베딩 모델을 설정해주세요

text = "클로바 스튜디오"
clovax_embeddings.embed_query(text)

# %%
# non-ssl
text_json = dict(text=text)
request_data = text_json

response_text = embedding_executor.execute(request_data)
print(request_data)
print(response_text)
# Out:
# {'text': '클로바 스튜디오'}
# [-0.6166992, -0.4165039, -2.1074219, 0.8017578, -0.49853516, 1.3476562, -1.3261719, 0.06732178, 0.0234375, -0.50341797, 0.55322266, -0.27612305, 0.5678711, -0.78564453, 0.6796875, 0.038146973, -0.8486328, -0.6035156, 0.51123047, 0.07965088, -0.6401367, -0.63671875, 0.11090088, -0.5493164, 1.6416016, -0.26098633, 1.0253906, -0.40893555, 0.33154297, -0.8769531, -0.6777344, -0.57373047, -0.020431519, -1.1015625, 0.5830078, -1.9179688, 0.5029297, 0.86621094, -2.4472656, 0.23706055, 0.22705078, 2.2851562, 0.6088867, -0.3737793, 0.19958496, -0.0044174194, -0.36547852, -0.44262695, -0.78222656, -0.40551758, 0.5419922, 0.56884766, 0.5102539, 0.5102539, -0.2800293, -0.22912598, 0.0703125, -1.3759766, -1.7197266, 0.5546875, -0.99902344, 0.6660156, -0.031021118, 0.21166992, 0.7011719, 0.91503906, -0.5629883, -0.14025879, -0.24206543, 0.4267578, -0.77441406, -0.3701172, 0.1204834, -0.17248535, -1.1767578, 0.73876953, -0.5522461, -1.0126953, -0.12890625, 1.8720703, 1.1689453, -0.60595703, -0.024978638, -0.6196289, -0.30664062, -0.56103516, 0.24560547, -0.109375, -0.5385742, -0.1340332, -0.87353516, -0.44726562, 1.2392578, -0.6816406, -0.6689453, -0.75390625, -0.8828125, 0.5917969, -0.7807617, 1.7089844, -0.36621094, -0.02947998, 0.9868164, -0.63134766, 0.5229492, -0.6225586, -0.7314453, 0.7836914, -0.43945312, -0.16809082, 0.1184082, 0.83935547, -1.3691406, -0.375, 0.7055664, -0.0038166046, -0.5415039, -1.1523438, -0.07684326, -0.30493164, 0.43554688, 1.0253906, 0.3642578, -0.48046875, -0.8408203, -0.5263672, 0.8574219, 0.046447754, -0.45581055, -0.3635254, 0.46020508, 0.52685547, -0.6582031, -0.40234375, -1.3544922, -1.1582031, -0.70458984, 0.39160156, -1.2558594, -0.19458008, 0.46557617, -1.1162109, -0.74609375, -0.4814453, -0.99072266, 0.14465332, 0.46923828, 0.5600586, -1.1728516, -0.4543457, -0.6928711, 0.67041016, -0.05307007, 0.16674805, 0.9277344, -0.33642578, -1.2714844, 0.52490234, 0.2734375, -0.26098633, 1.2714844, -0.5942383, -1.0039062, 0.45898438, 0.48339844, 0.25952148, 0.7324219, 1.0234375, 0.359375, 0.017211914, 0.67529297, 0.11199951, -1.0087891, -0.90283203, 0.4873047, -0.10772705, 0.5029297, 0.66259766, 0.5058594, -1.9619141, 0.74609375, 0.5722656, -0.76220703, -0.87402344, -0.74072266, -0.22436523, -0.06384277, 0.1586914, 0.6196289, 0.37109375, -0.42578125, -1.0595703, -0.30664062, -1.4707031, 0.29638672, 0.5078125, 0.4428711, 0.67089844, -2.2480469, -0.6171875, -1.9755859, 0.3725586, -0.9116211, -0.49536133, -1.2128906, 0.65478516, -0.017974854, 0.0592041, 0.2824707, 0.23718262, -1.0146484, 0.44262695, 1.34375, -1.1201172, -1.1679688, 1.4013672, -0.24230957, 1.6855469, -0.31298828, 0.054992676, -0.2944336, 1.6787109, 1.296875, 0.97021484, 0.20080566, -0.7504883, 0.7714844, 1.5849609, 0.5551758, -0.04559326, 0.15148926, -1.8427734, 0.46020508, -1.1884766, -0.47314453, -0.24255371, -2.046875, 0.62060547, 1.8466797, 0.3215332, -0.87109375, 0.73095703, -0.015899658, -0.84716797, 0.4560547, 1.4804688, 0.06933594, 0.4675293, 0.05895996, 0.37670898, -0.070129395, 0.38476562, -0.87597656, -0.02067566, 0.5371094, 0.9326172, -0.28979492, -0.7265625, 0.06274414, 0.31323242, 0.9375, -0.79785156, 0.6040039, 1.0039062, 0.25146484, -0.8676758, 0.6801758, 0.5073242, 0.12817383, -0.96777344, 1.3457031, -0.34106445, 0.28564453, -0.1373291, -1.1904297, 0.057403564, -0.12805176, -0.06750488, 2.1015625, 0.51123047, 0.20935059, -0.7392578, 0.24597168, 0.96435547, -0.17163086, 0.07196045, -0.31152344, 1.6298828, -0.10913086, -0.24414062, -0.68603516, 0.68359375, 1.1484375, 0.5878906, 0.27197266, 0.9995117, -0.81152344, -3.1503906, -0.9213867, -0.20092773, 1.9541016, -0.34448242, -0.034088135, 0.4345703, -0.43579102, -1.5087891, 2.0058594, -0.9428711, -0.9013672, -1.0458984, -0.2915039, 0.7324219, 0.05419922, 0.90966797, -0.73583984, 0.2980957, -1.3134766, -0.04724121, -0.22094727, -0.0068359375, 0.35107422, -0.3852539, -1.8583984, 0.024871826, -0.7807617, -0.79785156, -0.7363281, 1.1640625, 1.1933594, 0.38598633, 0.71191406, -0.5283203, 0.8 ...

# %%
from langchain_core.documents import Document
 
documents = []
 
for index, item in enumerate(chunked_html):
    doc = Document(
        page_content=str(item['page_content']),
        metadata={"source": item['metadata']},
        id=str(uuid4())
    )
    documents.append(doc)

# %%
# documents 구조 체크
for i, doc in enumerate(documents):
    print(f"Document {i}:")
    print(f"  Page Content: {doc.page_content[:100]}...")  # 첫 100자만 출력
    print(f"  Metadata: {doc.metadata}")
    print(f"  Page Content Type: {type(doc.page_content)}")
    print(f"  Metadata Type: {type(doc.metadata)}")
    print("-" * 40)
# Out:
# Document 0:
#   Page Content: Open in app Sign in Write Sign in How we write rebuttals Devi Parikh Follow 10 min read May 27, 2020...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 1:
#   Page Content: By Devi Parikh, Dhruv Batra, Stefan Lee We frequently find ourselves giving the same advice to diffe...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 2:
#   Page Content: So we thought we’d write it up. Our experience is with AI conferences (e.g., CVPR, ECCV, ICCV, NeurI...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 3:
#   Page Content: Why do we write rebuttals? In a phrase — to clarify and convince....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 4:
#   Page Content: Science is a deliberative process, and rebuttals are simply a stage in that process....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 5:
#   Page Content: Bill Freeman gave an excellent talk at the “Good Citizen of CVPR” panel at CVPR18....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 6:
#   Page Content: He talked about the idealized image of the peer review process that new members of a research commun...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 7:
#   Page Content: The reality, Bill describes, is more like a large crowded marketplace....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 8:
#   Page Content: It’s messy and it’s chaotic; different actors in the process are trying to achieve different goals, ...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 9:
#   Page Content: With this in mind, it is important to note who we write rebuttals for and what our goal is....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 10:
#   Page Content: We write rebuttals for two different audiences The reviewers, who have read your paper (to varying d...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 11:
#   Page Content: The AC, who is likely even less familiar with your work, and a good guiding principle is to assume t...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 12:
#   Page Content: Our goals are For the reviewers: clarify doubts, answer questions, correct misunderstandings, push b...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 13:
#   Page Content: For the AC: convince them that you have made a good-faith effort, present a representative summary o...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 14:
#   Page Content: In our experience, most new members of the research community focus on (1), but ignore (2)....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 15:
#   Page Content: An imperfect but useful metaphor for rebuttals is debate competitions....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 16:
#   Page Content: Yes, we are trying to convince our opponent (and this is where the metaphor is imperfect; reviewers ...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 17:
#   Page Content: But more importantly, we are trying to convince the judges, who will ultimately be making the decisi...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 18:
#   Page Content: Thus, all else being equal, it is more important to convince the judges of your arguments than chang...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 19:
#   Page Content: We provide concrete recommendations below, but a good short-hand is the following — would a neutral ...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 20:
#   Page Content: Itemize reviewer comments....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 21:
#   Page Content: We use a handy spreadsheet to organize individual comments/questions/concerns raised by each reviewe...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 22:
#   Page Content: Laying everything out in the same place helps identify common concerns and keeps us from missing any...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 23:
#   Page Content: Do this ASAP to identify any necessary new experiments (if the venue allows it) or analysis early. B...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 24:
#   Page Content: The sheet has a column for each author to reply to each reviewer comment....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 25:
#   Page Content: Dump your thoughts here in rough text without regard for style or length....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 26:
#   Page Content: Being convincing and concise is a subtractive process. Write a draft rebuttal....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 27:
#   Page Content: Turn your consensus in the sheet into concrete responses in a rebuttal draft. Write concisely but do...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 28:
#   Page Content: Cover every point and trim / prioritize them later. Review and revise....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 29:
#   Page Content: Reread the initial reviews and your sheet to make sure everything has been addressed....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 30:
#   Page Content: Prioritize major concerns and start working towards meeting space limitations....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 31:
#   Page Content: Example set of initial responses from authors is shown below....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 32:
#   Page Content: You’ll see more polished snippets of some of these responses through the rest of this post...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 33:
#   Page Content: As for putting together the rebuttal itself, below is a list of tips and principles we follow and be...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 34:
#   Page Content: Provide a summary of the reviews, highlighting positive things that reviewers said about your work....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 35:
#   Page Content: Rebuttals focus mostly on responding to perceived negatives, don’t let RACs forget about the strengt...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 36:
#   Page Content: Start with the biggest concerns that you have good answers for and work your way to less clear-cut r...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 37:
#   Page Content: Let reviewers speak for themselves, then respond directly....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 38:
#   Page Content: Quote the core of the reviewer’s question or concern concisely and completely....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 39:
#   Page Content: Then before saying anything else, respond to it directly....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 40:
#   Page Content: And then give details, describe context, or explain your position....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 41:
#   Page Content: “Are these averaged across multiple runs?”: “Yes, we averaged across 5 random seeds.”...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 42:
#   Page Content: “Are the segmentation masks used during training?”: “No, they are only used to evaluate our results....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 43:
#   Page Content: “So overall, the proposed approach needs more human annotations than the baseline.”: “Not quite....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 44:
#   Page Content: While the first few iterations of our approach need a human in the loop more often, as we collect mo...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 45:
#   Page Content: For typical dataset sizes, we use fewer annotations overall....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 46:
#   Page Content: E.g., for GNART20 with 10k images, our approach uses 2.4k human annotations while the baseline uses ...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 47:
#   Page Content: “Does your baseline match the one reported by Smith et al. at CVPR last year [43]?”: “Almost....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 48:
#   Page Content: The is a 0.1% difference in performance between [43]’s publicly available code and what is reported ...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 49:
#   Page Content: “Did you evaluate on realistic environments?”: “We disagree with the question’s premise....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 50:
#   Page Content: While these environments are simulated, they are highly photorealistic.”...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 51:
#   Page Content: “Why did you not compare to GMAP?“ “GMAP is prohibitively expensive in our setting....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 52:
#   Page Content: Our environments have a significantly larger state-space (10k) than BRIE (20) which has been used to...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 53:
#   Page Content: Back-of-the-envelope calculations suggest it would take 128 GPUS for 3 months to evaluate GMAP.”...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 54:
#   Page Content: Tip 4. Be conversational. Notice the conversational nature of the example responses above....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 55:
#   Page Content: It makes it easier for RACs to follow, and the responses are less likely to be perceived as being co...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 56:
#   Page Content: Don’t feel trapped to only discuss the quoted concern — also address the intent of the comment....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 57:
#   Page Content: For example, “Why didn’t you evaluate on GLORP3?” may generally be calling your experiments into que...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 58:
#   Page Content: Answer, but then point out that you’ve already evaluated on X,Y, and Z which should be sufficient!...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 59:
#   Page Content: Note that it is useful for other RACs to be reminded of your extensive experimental evaluation. A fi...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 60:
#   Page Content: Tip 6. Don’t be afraid of emphasis. “Row 2 in Table 4 shows exactly that.”...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 61:
#   Page Content: “We do NOT need a human-in-the-loop at test time.” Notice that many of the responses above are not j...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 62:
#   Page Content: Tip 7. Feel free to set the stage. If it seems like all reviewers missed a central point, a concise,...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 63:
#   Page Content: Tip 8....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 64:
#   Page Content: Keep things self-contained....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 65:
#   Page Content: Assume RACs don’t remember much about your paper and that they likely won’t read it again in detail....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 66:
#   Page Content: Tip 9....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 67:
#   Page Content: But get credit for details you already included....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 68:
#   Page Content: That said, if something a reviewer asked for was already in the paper, say so....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 69:
#   Page Content: Give them line/Table/Figure numbers, and then restate it in the rebuttal. The references back to the...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 70:
#   Page Content: (They are not necessarily to have RACs go back and look at the paper.)...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 71:
#   Page Content: [R1: baseline that retrieves images from caption]...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 72:
#   Page Content: As described in L341, 746, 772, round 0 is the caption. Thus the round 0 point in Fig 4a is the capt...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 73:
#   Page Content: Tip 10....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 74:
#   Page Content: Consolidate common concerns. Save space by responding to multiple reviewers at once if they share re...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 75:
#   Page Content: Color-code reviewers. Notice above the trick to color-code reviewers....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 76:
#   Page Content: Make it as easy as possible for reviewers to spot responses that are relevant to them — even when th...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 77:
#   Page Content: Tip 12....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 78:
#   Page Content: Stats speak louder than words....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 79:
#   Page Content: Rather than argue with RACs, give them data/stats to back your claim up....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 80:
#   Page Content: These can be statistics/analysis of your data or results. Or the results of additional experiments y...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 81:
#   Page Content: Every time you find yourself having a different opinion than the reviewer, ask if you can establish ...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 82:
#   Page Content: You can always provide the intuitive arguments after you’ve settled the issue with data....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 83:
#   Page Content: Tip 13. Don’t promise, do....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 84:
#   Page Content: Instead of saying “We will discuss Singh et al. in the paper.”, provide a discussion in the rebuttal...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 85:
#   Page Content: Instead of saying “We will explain what D_{RT} stands for in the paper”, explain what it stands for ...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 86:
#   Page Content: And then also add that you will add it to the paper....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 87:
#   Page Content: It makes it significantly easier for RACs to trust that you will make the promised changes. Tip 14. ...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 88:
#   Page Content: Plus, it is just the better thing to do — these are your colleagues! :)...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 89:
#   Page Content: Likewise, instead of arguing why a reviewer’s suggestion might not work, try it and see if it works....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 90:
#   Page Content: Maybe it will! Tip 15. Be transparent....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 91:
#   Page Content: Reviewers hinted at an additional experiment but the venue doesn’t allow it? Say so....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 92:
#   Page Content: They asked about intuitions about a trend but you don’t have any? Say that you’ve thought about it b...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 93:
#   Page Content: Don’t have enough GPUs to run the experiment they asked for?...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 94:
#   Page Content: Say so....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 95:
#   Page Content: Tip 16....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 96:
#   Page Content: Shine a spotlight on reviewers acting in bad-faith. In some circumstances, a reviewer may not be adh...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 97:
#   Page Content: Pointing out unreasonable or unsubstantiated comments and referencing other reviewers that disagree ...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 98:
#   Page Content: Tip 17. Acknowledge reviewer efforts....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 99:
#   Page Content: On the other hand, if a reviewer goes above and beyond to be constructive, thank them for it....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 100:
#   Page Content: Typo list?...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 101:
#   Page Content: Thank you. Pointers to relevant work? Thank you. Detailed musings about future work? Thank you. Add ...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 102:
#   Page Content: Tip 18. Don’t forget the humans on the other end....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 103:
#   Page Content: Keep in mind that this is not just a scientific but a sociopolitical interaction with other humans :...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 104:
#   Page Content: So decide whether you’d like to be argumentative and risk your reviewer taking a strong stand agains...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 105:
#   Page Content: Publishing AI Rebuttal -- -- Written by Devi Parikh...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 106:
#   Page Content: 1.7K Followers Research Director at Facebook AI Research. Associate Professor at Georgia Tech....
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 107:
#   Page Content: Generative Artist. Artificial Intelligence. Help Status About...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 108:
#   Page Content: Careers Press Blog...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 109:
#   Page Content: Privacy...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 110:
#   Page Content: Terms...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 111:
#   Page Content: Text to speech...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------
# Document 112:
#   Page Content: Teams...
#   Metadata: {'source': 'https://deviparikh.medium.com/how-we-write-rebuttals-dc84742fece1'}
#   Page Content Type: <class 'str'>
#   Metadata Type: <class 'dict'>
# ----------------------------------------

# %% [markdown]
# ### 5. VectorStore

# %%
import chromadb
from langchain_chroma import Chroma
 
# 임베딩 모델 정의
#clovax_embeddings = ClovaXEmbeddings(model='bge-m3')
 
# 로컬 클라이언트 경로 지정
client = chromadb.PersistentClient(path="./chroma_langchain_db") #저장할 로컬 경로
 
# Chroma 컬렉션 생성
chroma_collection = client.get_or_create_collection(
    name="clovastudiodatas_docs", #collection이 바뀔때마다 이름도 꼭 변경해줘야 합니다.
    metadata={"hnsw:space": "cosine"} #사용하는 임베딩 모델에 따라 ‘l2’, 'ip', ‘cosine’ 중에 사용
)
 
# Chroma 벡터 저장소 생성
vectorstore = Chroma(
    client=client,
    collection_name="clovastudiodatas_docs",
    embedding_function=clovax_embeddings
)
 
# tqdm으로 for 루프 감싸기
for doc in tqdm(documents, desc="Adding documents", total=len(documents)):
    #print(doc)
    doc_json = dict(text=doc.page_content)
    #print(doc_json)
    embeddings = embedding_executor.execute(doc_json)
    #print(embeddings)
    #embeddings = clovax_embeddings.embed_documents([doc.page_content])[0]
    # 문서 추가
    chroma_collection.add(
        ids=[str(uuid.uuid4())],  # 고유한 ID 생성
        documents=[doc.page_content],
        embeddings=[embeddings],
        metadatas=[doc.metadata]
    )
    time.sleep(1.1)  # 이용량 제어를 고려한 1초 이상의 딜레이, 필요에 따라 조정 가능
 
print("All documents have been added to the vectorstore.")

# %%
def embedding_wrapper(doc):
    query = doc[0].page_content
    query_json = dict(text=query)
    response = embedding_executor.execute(query_json)
    return response

# %%
import faiss
from langchain_community.vectorstores import FAISS
from langchain_community.docstore.in_memory import InMemoryDocstore
 
# 임베딩 모델 정의
clovax_embeddings = ClovaXEmbeddings(model='bge-m3')
 
# FAISS 벡터 저장소 생성
vectorstore_FAISS = FAISS(
    embedding_function=clovax_embeddings,
    index=faiss.IndexFlatIP(1024), # 임베딩 차원 크기
    docstore=InMemoryDocstore(),
    index_to_docstore_id={},
)
 
# tqdm으로 for 루프 감싸기
for doc in tqdm(documents, desc="Adding documents", total=len(documents)):
    embeddings = clovax_embeddings.embed_documents([doc.page_content])[0]
    # 문서 추가
    vectorstore_FAISS.add_documents(
        ids=[str(uuid.uuid4())],  # 고유한 ID 생성
        documents=[doc],  # 문자열만 전달
        embeddings=[embeddings]
    )
    time.sleep(1.4)  # 이용량 제어를 고려한 1초 이상의 딜레이, 필요에 따라 조정 가능
 
print("All documents have been added to the vectorstore.")
# Out:
# Adding documents:   0%|          | 0/113 [00:00<?, ?it/s]
# Adding documents:   0%|          | 0/113 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpx/_transports/default.py:72, in map_httpcore_exceptions()
#      71 try:
# ---> 72     yield
#      73 except Exception as exc:
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpcore/_sync/connection.py:99, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
# ---> 99     raise exc
#     101 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpcore/_sync/connection.py:76, in HTTPConnection.handle_request(self, request)
#      75 if self._connection is None:
# ---> 76     stream = self._connect(request)
#      78     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpcore/_sync/connection.py:154, in HTTPConnection._connect(self, request)
#     153 with Trace("start_tls", logger, request, kwargs) as trace:
# --> 154     stream = stream.start_tls(**kwargs)
#     155     trace.return_value = stream
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpcore/_backends/sync.py:168, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     167         self.close()
# --> 168         raise exc
#     169 return SyncStream(sock)
#
# File ~/miniconda3/envs/gpt/lib/python3.9/contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1129)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[107], line 18
#      16 # tqdm으로 for 루프 감싸기
#      17 for doc in tqdm(documents, desc="Adding documents", total=len(documents)):
# ---> 18     embeddings = clovax_embeddings.embed_documents([doc.page_content])[0]
#      19     # 문서 추가
#      20     vectorstore_FAISS.add_documents(
#      21         ids=[str(uuid.uuid4())],  # 고유한 ID 생성
#      22         documents=[doc],  # 문자열만 전달
#      23         embeddings=[embeddings]
#      24     )
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/langchain_community/embeddings/naver.py:178, in ClovaXEmbeddings.embed_documents(self, texts)
#     176 embeddings = []
#     177 for text in texts:
# --> 178     embeddings.append(self._embed_text(text))
#     179 return embeddings
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/langchain_community/embeddings/naver.py:165, in ClovaXEmbeddings._embed_text(self, text)
#     163 def _embed_text(self, text: str) -> List[float]:
#     164     payload = {"text": text}
# --> 165     response = self.client.post(url=self._api_url, json=payload)
#     166     _raise_on_error(response)
#     167     return response.json()["result"]["embedding"]
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpx/_client.py:1157, in Client.post(self, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1136 def post(
#    1137     self,
#    1138     url: URL | str,
#    (...)
#    1150     extensions: RequestExtensions | None = None,
#    1151 ) -> Response:
#    1152     """
#    1153     Send a `POST` request.
#    1154
#    1155     **Parameters**: See `httpx.request`.
#    1156     """
# -> 1157     return self.request(
#    1158         "POST",
#    1159         url,
#    1160         content=content,
#    1161         data=data,
#    1162         files=files,
#    1163         json=json,
#    1164         params=params,
#    1165         headers=headers,
#    1166         cookies=cookies,
#    1167         auth=auth,
#    1168         follow_redirects=follow_redirects,
#    1169         timeout=timeout,
#    1170         extensions=extensions,
#    1171     )
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpx/_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~/miniconda3/envs/gpt/lib/python3.9/contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     135     value = typ()
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#     142     return exc is not value
#
# File ~/miniconda3/envs/gpt/lib/python3.9/site-packages/httpx/_transports/default.py:89, in map_httpcore_exceptions()
#      86     raise
#      88 message = str(exc)
# ---> 89 raise mapped_exc(message) from exc
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1129)
